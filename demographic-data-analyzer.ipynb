# %%
import pandas as pd

# %%
df = pd.read_csv('data/adult.data.csv')
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
race_count = df['race'].value_counts().tolist()
print(race_count)
# Out:
# [27816, 3124, 1039, 311, 271]

# %%
average_age_men = df[df['sex'] == 'Male']['age'].mean()
print(average_age_men)
# Out:
# 39.43354749885268

# %%
percentage_bachelors = df[df['education'] == 'Bachelors'].shape[0] / df.shape[0] * 100
percentage_bachelors
# Out:
# 16.44605509658794

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
higher_education = df[df['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]
lower_education = df[~df['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]
higher_education
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 5       37           Private  284582    Masters             14
# 8       31           Private   45781    Masters             14
# ...    ...               ...     ...        ...            ...
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32544   31           Private  199655    Masters             14
# 32553   32           Private  116138    Masters             14
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
higher_education_rich = higher_education[higher_education['salary'] == '>50K']['salary'].count() / higher_education.shape[0] * 100
higher_education_rich
# Out:
# 46.535843011613935

# %%
df['hours-per-week'].min()

# %%
min_workweek = df[df['hours-per-week'] == df['hours-per-week'].min()]
num_min_workers = min_workweek[min_workweek['salary'] == '>50K']['salary'].count()/min_workweek.shape[0]*100
num_min_workers
df['native-country'].value_counts().fillna(0).sort_values(ascending=False).index[0]value_counts().fillna(0).sort_values(ascending=False).index[0]
# Out:
#   File "<ipython-input-136-d1b55dc77728>", line 4
#     df['native-country'].value_counts().fillna(0).sort_values(ascending=False).index[0]value_counts().fillna(0).sort_values(ascending=False).index[0]
#                                                                                        ^
# SyntaxError: invalid syntax

# %%
highest_earning_country1 = (df.loc[df['salary'] == ">50K", 'native-country'].value_counts()/ df['native-country'].value_counts()).max()

highest_earning_country1
# Out:
# 0.4186046511627907

# %%
highest_earning_country = df[df['salary'] == '>50K'].groupby('native-country')['native-country'].count().max()
highest_earning_country.
# Out:
# 7171

# %%
highest_country_percentage = (df.loc[df['salary'] == ">50K", 'native-country'].value_counts()/ df['native-country'].value_counts()).max() *100
round(highest_country_percentage, 1)
# Out:
# 41.9

# %%
race_count = df.groupby('race')['race'].count()
race_count
# Out:
# race
# Amer-Indian-Eskimo      311
# Asian-Pac-Islander     1039
# Black                  3124
# Other                   271
# White                 27816
# Name: race, dtype: int64

# %%
percentage_bachelors = (df[df['education'] == 'Bachelors'].shape[0] / df.shape[0] * 100)
round(percentage_bachelors, 1)
# Out:
# 16.4

# %%
df[(df['salary'] == ">50K") & (df['native-country'] == "India")]["occupation"].value_counts().idxmax()
# Out:
# 'Prof-specialty'

# %%
df['race'].value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64
